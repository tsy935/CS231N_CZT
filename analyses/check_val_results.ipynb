# %%
import numpy as np
import pickle

# %%
results_dir = '/mnt/disks/large/output/baseline_hog/train/train-03/best_val_results'

# %%
with open(results_dir, 'rb') as f:
    val_results = pickle.load(f)

# %%
print(val_results)
# Out:
# OrderedDict([('Loss', 0.1203134101389092), ('F2', 0.26035732624996577), ('F1', 0.1891783648434517), ('recall', 0.4814795554974126), ('precision', 0.16079457516501516), ('best_thresh', 0.02)])
