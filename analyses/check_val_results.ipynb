# %%
import numpy as np
import pickle

# %% [markdown]
# # Baseline results

# %%
results_dir = '/mnt/disks/large/output/baseline_featureExtract/train/train-10/best_val_results'

# %%
with open(results_dir, 'rb') as f:
    val_results = pickle.load(f)

# %%
print(val_results)
# Out:
# OrderedDict([('Loss', 0.09572809123512589), ('F2', 0.3212409754605985), ('F1', 0.23708716653542167), ('recall', 0.535653453689168), ('precision', 0.19802247271179002), ('best_thresh', 0.04)])

# %% [markdown]
# # CNN-RNN results

# %%
results_dir = '/mnt/disks/large/output/cnnrnn/train/train-08/best_val_results'

# %%
with open(results_dir, 'rb') as f:
    cnnrnn_val_results = pickle.load(f)

# %%
print(cnnrnn_val_results)
# Out:
# OrderedDict([('Loss', 0.19006256786458223), ('F2', 0.1967848420668349), ('F1', 0.12702404337558024), ('recall', 0.3417522094307809), ('precision', 0.08175604549542267)])
