# %%
import numpy as np
import pickle

# %% [markdown]
# # Baseline results

# %%
results_dir = '/mnt/disks/large/output/baseline_featureExtract/train/train-02/best_val_results'

# %%
with open(results_dir, 'rb') as f:
    val_results = pickle.load(f)

# %%
print(val_results)
# Out:
# OrderedDict([('Loss', 0.09630122976207034), ('F2', 0.32799360922712684), ('F1', 0.2469129785537394), ('recall', 0.5281815076457934), ('precision', 0.21193063766976428), ('best_thresh', 0.04)])

# %% [markdown]
# # CNN-RNN results
# ## Train ResNet last FC layer

# %%
#val_results_dir = '/mnt/disks/large/output/cnnrnn/train/train-11/best_val_results'

# %%
#with open(val_results_dir, 'rb') as f:
#    cnnrnn_val_results = pickle.load(f)

# %%
#print(cnnrnn_val_results)

# %%
## BEST DEV SET RESULTS FOR CNN-RNN
val_beam_dir = '/mnt/disks/large/output/cnnrnn/test/test-07/dev_results'
with open(val_beam_dir, 'rb') as f:
    val_beam_results = pickle.load(f)

print(val_beam_results)
# Out:
# OrderedDict([('Loss', 0), ('F2', 0.39075307979372276), ('F1', 0.26276949774581476), ('recall', 0.6194484781091923), ('precision', 0.17386119855657153)])

# %%
## BEST TEST SET RESULTS FOR CNN-RNN
test_beam_dir = '/mnt/disks/large/output/cnnrnn/test/test-05/test_results'
with open(test_beam_dir, 'rb') as f:
    test_beam_results = pickle.load(f)

print(test_beam_results)
# Out:
# OrderedDict([('Loss', 0), ('F2', 0.3931713648179717), ('F1', 0.26446853736267895), ('recall', 0.621561137275423), ('precision', 0.17503284485680426)])

# %% [markdown]
# # Fine-tuned baseline results

# %%
results_dir = '/mnt/disks/large/output/baseline_featureExtract/train/train-02/best_val_results'

# %%
with open(results_dir, 'rb') as f:
    val_results = pickle.load(f)

# %%
print(val_results)
# Out:
# OrderedDict([('Loss', 0.09630122976207034), ('F2', 0.32799360922712684), ('F1', 0.2469129785537394), ('recall', 0.5281815076457934), ('precision', 0.21193063766976428), ('best_thresh', 0.04)])
